# %% [markdown]
# <a href="https://colab.research.google.com/github/lianbelian/TUGAS-PAK-PRAYIT-PBO/blob/main/geometri_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Modul geometri.py berisi fungsi terkait geometri

def hitung_luas_persegi(sisi):
	return sisi * sisi

def hitung_luas_persegi_panjang(panjang, lebar):
	return panjang * lebar

def hitung_luas_lingkaran(jari_jari):
	return 3.14 * (jari_jari ** 2)

def hello_pray():
	return "Echo hallo pray"
