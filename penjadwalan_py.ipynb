# %% [markdown]
# <a href="https://colab.research.google.com/github/lianbelian/TUGAS-PAK-PRAYIT-PBO/blob/main/penjadwalan_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile penjadwalan.py
import penjadwalan

def main():
	print(penjadwalan.sapa_sistem())
	print("=" * 30)

	# Membuat objek jadwal kelas
	matkul1 = penjadwalan.MataKuliah("TRK101", "Pemrograman Python", "Ir. Prayitno", "Senin", "08.00 - 10.00")
	matkul2 = penjadwalan.MataKuliah("TRK102", "Sistem Operasi", "Dosen B", "Selasa", "10.00 - 12.00")

	# Menampilkan data
	matkul1.tampilkan_jadwal()
	matkul2.tampilkan_jadwal()

if __name__ == "__main__":
	main()
# Out:
# Writing penjadwalan.py
